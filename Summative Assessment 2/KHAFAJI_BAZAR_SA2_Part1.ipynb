# %%
import polars as pl
import fitter
from datetime import date 
import requests as rq
from distfit import distfit

# %% [markdown]
# # Getting Bitcoin Historical Index

# %%
# Get btc candlestick data from 2012 to 2021 from csv file

btc = pl.read_csv("bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv", infer_schema_length = 2000).select(
    pl.col("Timestamp"),pl.col("Open"),pl.col("High"),pl.col("Low"),pl.col("Close"),pl.col("Volume_(BTC)").alias("Volume")
).fill_nan(None).drop_nulls().with_columns(
    
    # Add return column
    Return = pl.col("Close") - pl.col("Open")
)
print(btc)
# Out:
# shape: (3_613_769, 7)
# ┌────────────┬──────────┬──────────┬──────────┬──────────┬───────────┬────────┐
# │ Timestamp  ┆ Open     ┆ High     ┆ Low      ┆ Close    ┆ Volume    ┆ Return │
# │ ---        ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---       ┆ ---    │
# │ i64        ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64       ┆ f64    │
# ╞════════════╪══════════╪══════════╪══════════╪══════════╪═══════════╪════════╡
# │ 1325317920 ┆ 4.39     ┆ 4.39     ┆ 4.39     ┆ 4.39     ┆ 0.455581  ┆ 0.0    │
# │ 1325346600 ┆ 4.39     ┆ 4.39     ┆ 4.39     ┆ 4.39     ┆ 48.0      ┆ 0.0    │
# │ 1325350740 ┆ 4.5      ┆ 4.57     ┆ 4.5      ┆ 4.57     ┆ 37.862297 ┆ 0.07   │
# │ 1325350800 ┆ 4.58     ┆ 4.58     ┆ 4.58     ┆ 4.58     ┆ 9.0       ┆ 0.0    │
# │ 1325391360 ┆ 4.58     ┆ 4.58     ┆ 4.58     ┆ 4.58     ┆ 1.502     ┆ 0.0    │
# │ …          ┆ …        ┆ …        ┆ …        ┆ …        ┆ …         ┆ …      │
# │ 1617148560 ┆ 58714.31 ┆ 58714.31 ┆ 58686.0  ┆ 58686.0  ┆ 1.384487  ┆ -28.31 │
# │ 1617148620 ┆ 58683.97 ┆ 58693.43 ┆ 58683.97 ┆ 58685.81 ┆ 7.294848  ┆ 1.84   │
# │ 1617148680 ┆ 58693.43 ┆ 58723.84 ┆ 58693.43 ┆ 58723.84 ┆ 1.705682  ┆ 30.41  │
# │ 1617148740 ┆ 58742.18 ┆ 58770.38 ┆ 58742.18 ┆ 58760.59 ┆ 0.720415  ┆ 18.41  │
# │ 1617148800 ┆ 58767.75 ┆ 58778.18 ┆ 58755.97 ┆ 58778.18 ┆ 2.712831  ┆ 10.43  │
# └────────────┴──────────┴──────────┴──────────┴──────────┴───────────┴────────┘

# %%
# Add in / concatenate data from 2021 - 2024 to the dataset
for p in range(1,8):
    path = "BAZAR_KHAFAJI_BTCUSD_FROM2021_"+str(p)+".csv"
    btc_temp = pl.read_csv(path, infer_schema_length = 2000000).select(
        pl.col("timestamp").alias("Timestamp"),
        pl.col("open").cast(pl.Float64).alias("Open"),
        pl.col("high").cast(pl.Float64).alias("High"),
        pl.col("low").cast(pl.Float64).alias("Low"),
        pl.col("close").cast(pl.Float64).alias("Close"),
        pl.col("volume").cast(pl.Float64).alias("Volume")
    ).with_columns(
        
        # Add return column
        Return = pl.col("Close") - pl.col("Open")
    )
    
    btc = pl.concat([btc,btc_temp]).sort("Timestamp")
print(btc)
# Out:
# shape: (5_216_489, 7)
# ┌────────────┬─────────┬─────────┬─────────┬─────────┬───────────┬────────┐
# │ Timestamp  ┆ Open    ┆ High    ┆ Low     ┆ Close   ┆ Volume    ┆ Return │
# │ ---        ┆ ---     ┆ ---     ┆ ---     ┆ ---     ┆ ---       ┆ ---    │
# │ i64        ┆ f64     ┆ f64     ┆ f64     ┆ f64     ┆ f64       ┆ f64    │
# ╞════════════╪═════════╪═════════╪═════════╪═════════╪═══════════╪════════╡
# │ 1325317920 ┆ 4.39    ┆ 4.39    ┆ 4.39    ┆ 4.39    ┆ 0.455581  ┆ 0.0    │
# │ 1325346600 ┆ 4.39    ┆ 4.39    ┆ 4.39    ┆ 4.39    ┆ 48.0      ┆ 0.0    │
# │ 1325350740 ┆ 4.5     ┆ 4.57    ┆ 4.5     ┆ 4.57    ┆ 37.862297 ┆ 0.07   │
# │ 1325350800 ┆ 4.58    ┆ 4.58    ┆ 4.58    ┆ 4.58    ┆ 9.0       ┆ 0.0    │
# │ 1325391360 ┆ 4.58    ┆ 4.58    ┆ 4.58    ┆ 4.58    ┆ 1.502     ┆ 0.0    │
# │ …          ┆ …       ┆ …       ┆ …       ┆ …       ┆ …         ┆ …      │
# │ 1713282960 ┆ 62045.0 ┆ 62071.0 ┆ 62016.0 ┆ 62016.0 ┆ 0.041638  ┆ -29.0  │
# │ 1713283020 ┆ 61977.0 ┆ 62004.0 ┆ 61873.0 ┆ 61873.0 ┆ 0.429763  ┆ -104.0 │
# │ 1713283080 ┆ 61892.0 ┆ 61938.0 ┆ 61852.0 ┆ 61912.0 ┆ 1.022414  ┆ 20.0   │
# │ 1713283140 ┆ 61884.0 ┆ 61906.0 ┆ 61794.0 ┆ 61794.0 ┆ 0.136812  ┆ -90.0  │
# │ 1713283200 ┆ 61792.0 ┆ 61800.0 ┆ 61736.0 ┆ 61798.0 ┆ 1.364558  ┆ 6.0    │
# └────────────┴─────────┴─────────┴─────────┴─────────┴───────────┴────────┘

# %%
#download the dataset for possible use outside the program
btc.write_csv("BAZAR_KHAFAJI_BTCUSD_2012_2024.csv", separator=",")

# %% [markdown]
# # Fitting the return of the BTC return data

# %%
# show the histogram of the return data

import matplotlib.pyplot as plt

btc_return = btc.select("Return").to_numpy()

plt.hist(btc_return, bins=4000, label = "Bitcoin Return Histogram")
plt.ylim(top = 150000)
plt.show()

# %%
# use distfit module to get which probability distribution best fits the data
# Distfit module will give the Residual Sum of Square (RSS)
# RSS closer to 0 signifies that the distribution fits the data better.

dfit2 = distfit(distr = 'full', bins=4000)
dfit2.fit_transform(btc_return)
dfit2.plot_summary()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [alpha          ] [145. sec] [RSS: 0.12806] [loc=-1794.059 scale=111.835]
# [distfit] >INFO> [anglit         ] [64.2 sec] [RSS: 0.125095] [loc=-27.675 scale=1814.233]
# [distfit] >INFO> [arcsine        ] [108. sec] [RSS: 0.126014] [loc=-1567.110 scale=2964.330]
# [distfit] >INFO> [beta           ] [225. sec] [RSS: 0.108036] [loc=-12241.165 scale=20910.422]
# [distfit] >INFO> [betaprime      ] [261. sec] [RSS: 0.129534] [loc=-927.230 scale=3.658]
# [distfit] >INFO> [bradford       ] [97.9 sec] [RSS: 0.125404] [loc=-1154.110 scale=2440.110]
# [distfit] >INFO> [burr           ] [879. sec] [RSS: 0.118162] [loc=-2468.314 scale=2134.164]
# [distfit] >INFO> [cauchy         ] [16.4 sec] [RSS: 0.0383527] [loc=0.014 scale=1.554]
# [distfit] >INFO> [chi            ] [176. sec] [RSS: 0.125734] [loc=-68.000 scale=2.439]
# [distfit] >INFO> [chi2           ] [198. sec] [RSS: 0.124371] [loc=-866.164 scale=58.858]
# [distfit] >INFO> [cosine         ] [121. sec] [RSS: 0.124941] [loc=-84.945 scale=471.788]
# [distfit] >INFO> [dgamma         ] [165. sec] [RSS: 0.050533] [loc=-0.000 scale=19.984]
# [distfit] >INFO> [dweibull       ] [305. sec] [RSS: 0.0575672] [loc=0.000 scale=9.060]
# [distfit] >INFO> [erlang         ] [181. sec] [RSS: 0.122971] [loc=-1026.202 scale=28.494]
# [distfit] >INFO> [expon          ] [0.02 sec] [RSS: 0.125625] [loc=-2279.130 scale=2279.161]
# [distfit] >INFO> [exponnorm      ] [67.8 sec] [RSS: 0.10634] [loc=-9.617 scale=18.469]
# [distfit] >INFO> [exponweib      ] [663. sec] [RSS: 0.166311] [loc=-927.230 scale=1.067]
# [distfit] >INFO> [exponpow       ] [643. sec] [RSS: 1.03666] [loc=-2269.478 scale=0.985]
# [distfit] >INFO> [f              ] [383. sec] [RSS: 0.137792] [loc=-1113.000 scale=1.868]
# [distfit] >INFO> [fatiguelife    ] [364. sec] [RSS: 0.127453] [loc=-1008.020 scale=3.457]
# [distfit] >INFO> [fisk           ] [783. sec] [RSS: 0.144848] [loc=-1607.380 scale=45.666]
# [distfit] >INFO> [foldcauchy     ] [346. sec] [RSS: 0.242627] [loc=-923.944 scale=2.999]
# [distfit] >INFO> [foldnorm       ] [625. sec] [RSS: 0.125728] [loc=-3261.577 scale=0.000]
# [distfit] >INFO> [genlogistic    ] [113. sec] [RSS: 0.0955312] [loc=2.328 scale=6.604]
# [distfit] >INFO> [genpareto      ] [402. sec] [RSS: 0.12999] [loc=-1607.380 scale=34.381]
# [distfit] >INFO> [gennorm        ] [254. sec] [RSS: 0.0351114] [loc=0.000 scale=0.002]
# [distfit] >INFO> [genexpon       ] [1032 sec] [RSS: 0.125419] [loc=-733.306 scale=2.209]
# [distfit] >INFO> [genextreme     ] [1366 sec] [RSS: 0.123994] [loc=-23.628 scale=259.639]
# [distfit] >INFO> [gausshyper     ] [2102 sec] [RSS: 0.125042] [loc=-1567.112 scale=2779.897]
# [distfit] >INFO> [gamma          ] [189. sec] [RSS: 0.116074] [loc=-1371.877 scale=1.578]
# [distfit] >INFO> [gengamma       ] [643. sec] [RSS: 0.126746] [loc=-979.010 scale=47.278]
# [distfit] >INFO> [genhalflogistic] [332. sec] [RSS: 0.125507] [loc=-2279.130 scale=3838.446]
# [distfit] >INFO> [gibrat         ] [138. sec] [RSS: 0.125352] [loc=-1113.003 scale=1112.794]
# [distfit] >INFO> [gompertz       ] [174. sec] [RSS: 0.125728] [loc=-1898.740 scale=0.000]
# [distfit] >INFO> [gumbel_r       ] [7.87 sec] [RSS: 0.123277] [loc=-17.778 scale=184.565]
# [distfit] >INFO> [gumbel_l       ] [8.24 sec] [RSS: 0.122857] [loc=15.567 scale=156.983]
# [distfit] >INFO> [halfcauchy     ] [80.4 sec] [RSS: 0.125452] [loc=-1113.000 scale=1113.852]
# [distfit] >INFO> [halflogistic   ] [110. sec] [RSS: 0.125403] [loc=-1113.000 scale=721.187]
# [distfit] >INFO> [halfnorm       ] [87.9 sec] [RSS: 0.126082] [loc=-1607.380 scale=835.294]
# [distfit] >INFO> [halfgennorm    ] [281. sec] [RSS: 0.125064] [loc=-1113.000 scale=1382.135]
# [distfit] >INFO> [hypsecant      ] [32.4 sec] [RSS: 0.0920745] [loc=0.012 scale=8.062]
# [distfit] >INFO> [invgamma       ] [207. sec] [RSS: 0.126332] [loc=-1641.566 scale=24.992]
# [distfit] >INFO> [invgauss       ] [243. sec] [RSS: 0.124765] [loc=-1127.391 scale=6248.336]
# [distfit] >INFO> [invweibull     ] [297. sec] [RSS: 0.195687] [loc=-945.240 scale=2.197]
# [distfit] >INFO> [johnsonsb      ] [491. sec] [RSS: 0.111756] [loc=-5716.955 scale=7824.726]
# [distfit] >INFO> [johnsonsu      ] [459. sec] [RSS: 0.0915837] [loc=-0.000 scale=0.000]
# [distfit] >INFO> [laplace        ] [0.13 sec] [RSS: 0.0821364] [loc=0.000 scale=8.842]
# [distfit] >INFO> [levy           ] [152. sec] [RSS: 0.125525] [loc=-1568.162 scale=1565.433]
# [distfit] >INFO> [logistic       ] [5.81 sec] [RSS: 0.0959599] [loc=0.012 scale=7.381]
# [distfit] >INFO> [loggamma       ] [135. sec] [RSS: 0.108499] [loc=-4266.752 scale=644.858]
# [distfit] >INFO> [loglaplace     ] [243. sec] [RSS: 0.179217] [loc=-927.230 scale=3.377]
# [distfit] >INFO> [lognorm        ] [418. sec] [RSS: 0.129852] [loc=-1607.380 scale=128.373]
# [distfit] >INFO> [lomax          ] [99.0 sec] [RSS: 0.132671] [loc=-927.230 scale=3.377]
# [distfit] >INFO> [maxwell        ] [142. sec] [RSS: 0.124871] [loc=-1109.178 scale=586.964]
# [distfit] >INFO> [mielke         ] [518. sec] [RSS: nan] [loc=-337542055869.552 scale=337542054182.558]
# [distfit] >INFO> [nakagami       ] [177. sec] [RSS: 0.108028] [loc=-35003.132 scale=35003.158]
# [distfit] >INFO> [norm           ] [0.09 sec] [RSS: 0.108006] [loc=0.031 scale=22.781]
# [distfit] >INFO> [pareto         ] [13.3 sec] [RSS: 0.125625] [loc=-274877909223.130 scale=274877906944.000]
# [distfit] >INFO> [pearson3       ] [455. sec] [RSS: 0.108004] [loc=0.042 scale=22.776]
# [distfit] >INFO> [powerlaw       ] [4.10 sec] [RSS: 0.125496] [loc=-2279.131 scale=4230.451]
# [distfit] >INFO> [powerlognorm   ] [528. sec] [RSS: 0.128863] [loc=-1113.000 scale=3.535]
# [distfit] >INFO> [powernorm      ] [165. sec] [RSS: 0.107894] [loc=8.396 scale=25.455]
# [distfit] >INFO> [rdist          ] [270. sec] [RSS: 0.12507] [loc=-320.638 scale=1965.380]
# [distfit] >INFO> [rayleigh       ] [1.85 sec] [RSS: 0.125376] [loc=-2279.130 scale=1611.691]
# [distfit] >INFO> [rice           ] [469. sec] [RSS: 0.125728] [loc=-3261.577 scale=0.000]
# [distfit] >INFO> [recipinvgauss  ] [362. sec] [RSS: 0.108463] [loc=-1227.680 scale=0.451]
# [distfit] >INFO> [semicircular   ] [77.2 sec] [RSS: 0.125187] [loc=-66.610 scale=1279.390]
# [distfit] >INFO> [t              ] [477. sec] [RSS: 0.125312] [loc=0.000 scale=0.000]
# [distfit] >INFO> [triang         ] [346. sec] [RSS: 0.124915] [loc=-1628.867 scale=3026.088]
# [distfit] >INFO> [truncexpon     ] [64.7 sec] [RSS: 0.125376] [loc=-1346.000 scale=6285.881]
# [distfit] >INFO> [truncnorm      ] [39.1 sec] [RSS: 0.108006] [loc=0.031 scale=22.781]
# [distfit] >INFO> [tukeylambda    ] [8334 sec] [RSS: 0.124703] [loc=-0.000 scale=0.000]
# [distfit] >INFO> [uniform        ] [0.03 sec] [RSS: 0.125504] [loc=-2279.130 scale=4230.450]
# [distfit] >INFO> [vonmises       ] [176. sec] [RSS: 2.51527e+65] [loc=0.038 scale=0.000]
# [distfit] >INFO> [vonmises_line  ] [113. sec] [RSS: 0.123988] [loc=29.335 scale=376.702]
# [distfit] >INFO> [wald           ] [83.5 sec] [RSS: 0.125269] [loc=-1113.441 scale=1800.298]
# [distfit] >INFO> [weibull_min    ] [182. sec] [RSS: 0.121514] [loc=-1607.396 scale=1619.458]
# [distfit] >INFO> [weibull_max    ] [223. sec] [RSS: 0.129751] [loc=918.450 scale=2.174]
# [distfit] >INFO> [wrapcauchy     ] [175. sec] [RSS: 0.125366] [loc=-1404.570 scale=416.565]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [distfit] >INFO> Ploting Summary.
# (<Figure size 2000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Gennorm (best fit)'}, xlabel='Probability Density Function (PDF)', ylabel='RSS (goodness of fit test)'>)

# %%
# use distfit module to get which probability distribution best fits the data
# Distfit module will give the Residual Sum of Square (RSS)
# RSS closer to 0 signifies that the distribution fits the data better.

# This uses the top 5 best fitting distributions above, and the normal distribution,
# so that the RSS plot could be looked at better
dfit = distfit(distr = ['gennorm',
                        'cauchy',
                        'dgamma',
                        'dweibull',
                        'laplace',
                        'norm'] ,bins=4000)
dfit.fit_transform(btc_return)
dfit.plot_summary()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [gennorm ] [236. sec] [RSS: 0.0351114] [loc=0.000 scale=0.002]
# [distfit] >INFO> [cauchy  ] [20.7 sec] [RSS: 0.0383527] [loc=0.014 scale=1.554]
# [distfit] >INFO> [dgamma  ] [172. sec] [RSS: 0.050533] [loc=-0.000 scale=19.984]
# [distfit] >INFO> [dweibull] [289. sec] [RSS: 0.0575672] [loc=0.000 scale=9.060]
# [distfit] >INFO> [laplace ] [0.14 sec] [RSS: 0.0821364] [loc=0.000 scale=8.842]
# [distfit] >INFO> [norm    ] [0.10 sec] [RSS: 0.108006] [loc=0.031 scale=22.781]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [distfit] >INFO> Ploting Summary.
# (<Figure size 2000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Gennorm (best fit)'}, xlabel='Probability Density Function (PDF)', ylabel='RSS (goodness of fit test)'>)

# %% [markdown]
# The best distribution that fit the BTCUSD return data is the Generalized Normal probability distribution

# %% [markdown]
# # Getting ETH historical index

# %%
# Create empty dataframe
eth = pl.DataFrame()

#Read and concatenate ETH candlestick data
for p in range(1,5):
    path = "BAZAR_KHAFAJI_ETHUSD_"+str(p)+".csv"
    eth_sub = pl.read_csv(path)
    eth = pl.concat([eth,eth_sub]).with_columns(
        
        # Add return column
        Return = pl.col("close") - pl.col("open")
    )

#print table
print(eth)

# %%
# Save ETHUSD data for use outside of the program
eth.write_csv("BAZAR_KHAFAJI_ETHUSD_AUG2017_APR2024.csv", separator=",")
